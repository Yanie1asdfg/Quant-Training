# %%
# import jqdatasdk
# jqdatasdk.auth("18523900898","189Qwert")
# df = jqdatasdk.get_price('600519.XSHG',count=10,end_date = '2020-08-01',frequency='daily')
# df
# Out:
# auth success
#                open    close     high      low     volume         money
# 2020-07-20  1652.50  1636.96  1663.99  1588.88  4528033.0  7.363823e+09
# 2020-07-21  1646.64  1668.00  1702.80  1630.99  4196950.0  7.026353e+09
# 2020-07-22  1658.00  1678.08  1710.00  1658.00  3920121.0  6.637265e+09
# 2020-07-23  1672.00  1676.00  1691.00  1650.00  3432052.0  5.739050e+09
# 2020-07-24  1654.85  1595.30  1666.00  1585.00  7875201.0  1.270594e+10
# 2020-07-27  1616.01  1622.55  1629.80  1600.00  3878817.0  6.279664e+09
# 2020-07-28  1630.00  1670.00  1680.00  1630.00  5491152.0  9.133722e+09
# 2020-07-29  1690.00  1672.00  1690.00  1633.00  5074843.0  8.411790e+09
# 2020-07-30  1671.20  1680.00  1700.59  1670.50  3837304.0  6.486855e+09
# 2020-07-31  1685.00  1678.18  1705.00  1646.00  4068474.0  6.846747e+09

# %%
from pandas_datareader import data as web
import time
while True:
    df = web.get_quote_yahoo('SHLL')
    print(df)
    print(df.preMarketPrice[0])
    print(df.price[0])
    time.sleep(3)
# Out:
#      language region quoteType         quoteSourceName  triggerable currency  \
# SHLL    en-US     US    EQUITY  Nasdaq Real Time Price         True      USD
#
#      exchange                   shortName                    longName  \
# SHLL      NYQ  Tortoise Acquisition Corp.  Tortoise Acquisition Corp.
#
#        messageBoardId  ... fiftyDayAverageChangePercent twoHundredDayAverage  \
# SHLL  finmb_601320765  ...                     0.995511            15.820424
#
#       twoHundredDayAverageChange twoHundredDayAverageChangePercent  \
# SHLL                   36.779575                          2.324816
#
#        marketCap priceToBook  sourceInterval  exchangeDataDelayedBy  \
# SHLL  1532032768   305.81393              15                      0
#
#                displayName  price
# SHLL  Tortoise Acquisition   52.6
#
# [1 rows x 59 columns]
#      language region quoteType         quoteSourceName  triggerable currency  \
# ...

# %%
from email import encoders
from email.header import Header
from email.mime.text import MIMEText
from email.utils import parseaddr, formataddr
import smtplib
def _format_addr(s):
    name, addr = parseaddr(s)
    return formataddr((\
                       Header(name, 'utf-8').encode(), \
                       addr.encode('utf-8').decode('unicode_escape') if isinstance(addr, str) else addr))          

def send_email(title,s):
    from_addr = '1707058954@qq.com'
    password = 'fckvpiwsqghjbibb'
    to_addr = '1721876035@qq.com'
    smtp_server = 'smtp.qq.com'

    msg = MIMEText(s, 'html', 'utf-8')
    msg['From'] = _format_addr(u'美股推送 <%s>' % from_addr)
    msg['To'] = _format_addr(u'管理员 <%s>' % to_addr)
    # date = context.current_dt.date()
    # title = str(date)+'选股推送'
    msg['Subject'] = Header(title, 'utf-8').encode()

    server = smtplib.SMTP(smtp_server, 25)
    server.set_debuglevel(1)
    server.login(from_addr, password)
    server.sendmail(from_addr, [to_addr], msg.as_string())
    server.quit()

# %%
codelist = ['AAL','AAL','AAL','CCL','NCLH','SHLL']
namelist =['美国航空','美国航空','美国航空','嘉年华游轮','挪威游轮','Tor']
pricelist=[13,12,11,12,12,22]
switchlist=[0,0,0,0,0,0]
tuplelist = list(zip(codelist,namelist,pricelist,switchlist))
stockinfo =pd.DataFrame(tuplelist,columns=['code','name','price','switch'])
stockinfo1 = stockinfo
print(stockinfo)
# Out:
#    code   name  price  switch
# 0   AAL   美国航空     13       0
# 1   AAL   美国航空     12       0
# 2   AAL   美国航空     11       0
# 3   CCL  嘉年华游轮     12       0
# 4  NCLH   挪威游轮     12       0
# 5  SHLL    Tor     22       0

# %%
from datetime import datetime
import time
from pandas_datareader import data as web
# print(datetime.today(),type(datetime.now().date()))
print(datetime.now())
# print(datetime.now().hour)
# print(datetime.now().minute)
# print(datetime.now().second)
hour=[19,20,21,22,23,0,1,2,3,4,5]
'''open = True
operation = 0 
oldm = -1
while open:
    s = datetime.now().second
    m = datetime.now().minute
    if oldm !=m:
        operation = 0
    if s==0.00000000 and m%1==0 and operation == 0:
        print(m,s)
        operation = 1
        oldm = m'''

while True:
    s = datetime.now().second
    m = datetime.now().minute
    h = datetime.now().hour
    if h==6 and s==0 and m ==0:
        stockinfo = stockinfo1
        print(stockinfo['switch'].tolist())
        print('==========开关已清空============')
    if s==0 and m==0 and h in hour:
        print(datetime.now())
        for i in stockinfo.index:
#             print(i)
            df = web.get_quote_yahoo(stockinfo.at[i,'code'])
            print(df.shortName[0]+': '+str(df.price[0]))
            if df.price[0]<=stockinfo.at[i,'price']+0.1 and df.price[0]>=stockinfo.at[i,'price']-0.1:
                print(stockinfo.at[i,'code']+str(stockinfo.loc[i,'price']))
                if stockinfo.at[i,'switch']==0:
                    title = '美股 '+stockinfo.at[i,'name']+' 通知'
                    # message = '期货:'+ g.future_code +'\n'+'实时价格:'+str(tick[0][0])+'\n'+'该期货已满足条件'
                    message = '<p>======通知====== </p>'
                    # message += '<p>期货代码：</p>'
                    message += '<p>条件触发时间：'+str(datetime.now())+'</p>'
                    message += '<table cellpadding="10">'+'<tr bgcolor="Crimson"><th>代码</th><th>名称</th><th>实时价格</th><th>限定价格</th></tr>'
                    message += '<tr bgcolor= "WhiteSmoke">'+'<td>'+stockinfo.at[i,'code']+'</td><td><font color="Blue">'+df.shortName[0]+stockinfo.at[i,'name']+'</td><td>'+str(df.price[0])+'</td><td>'+str(stockinfo.at[i,'price'])+'</td></tr>'+'</table>'
                    print(df.shortName[0]+'价格超过了'+str(stockinfo.at[i,'price']))
                    send_email(title,message)
                    stockinfo.at[i,'switch']=1
                    print(stockinfo['switch'].tolist())
                    time.sleep(3)
                
#         time.sleep(59)
        
        
# if datetime.today().hour==0 and context.current_dt.minute==0:
    
#     g.stockinfo3=g.stockinfo4
# for i in g.stockinfo3.index:
#     print(g.stockinfo3.at[i,'code'])
#     df = web.get_quote_yahoo(g.stockinfo3.at[i,'code'])
#     print(df.shortName[0]+': '+str(df.price[0]))
#     if df.price[0]<=g.stockinfo3.at[i,'price']:
#         print(g.stockinfo3.at[i,'code']+str(g.stockinfo3.loc[i,'price']))
#         if g.stockinfo3.at[i,'switch']==0:
#             title = '美股 '+g.stockinfo3.at[i,'name']+' 通知'
#             # message = '期货:'+ g.future_code +'\n'+'实时价格:'+str(tick[0][0])+'\n'+'该期货已满足条件'
#             message = '<p>======通知====== </p>'
#             # message += '<p>期货代码：</p>'
#             message += '<p>条件触发时间：'+str(context.current_dt)+'</p>'
#             message += '<table cellpadding="10">'+'<tr bgcolor="Crimson"><th>代码</th><th>名称</th><th>实时价格</th><th>限定价格</th></tr>'
#             message += '<tr bgcolor= "WhiteSmoke">'+'<td>'+g.stockinfo3.at[i,'code']+'</td><td><font color="Blue">'+df.shortName[0]+g.stockinfo3.at[i,'name']+'</td><td>'+str(df.price[0])+'</td><td>'+str(g.stockinfo3.at[i,'price'])+'</td></tr>'+'</table>'
#             print(df.shortName[0]+'价格超过了'+str(g.stockinfo3.at[i,'price']))
#             send_email(title,message)
#             g.stockinfo3.at[i,'switch']=1
#             print(g.stockinfo3['switch'].tolist())
# Out:
# 2020-09-03 07:07:07.855995
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-c7ebefb6070a> in <module>
#      23 while True:
#      24     s = datetime.now().second
# ---> 25     m = datetime.now().minute
#      26     h = datetime.now().hour
#      27     if h==6 and s==0 and m ==0:
#
# KeyboardInterrupt:
